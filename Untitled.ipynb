# %%
import pickle as pk
import gzip
with gzip.open("mp_20_test_cin_prep.pkl.gz", 'rb') as f:
    test_data = pk.load(f)
test_data[0]
# Out:
# ('mp-1225695',
#  "# generated using pymatgen\ndata_Cu2Ni2\nloop_\n _atom_type_symbol\n _atom_type_electronegativity\n _atom_type_radius\n _atom_type_ionic_radius\n  Cu  1.9000  1.3500  0.8200\n  Ni  1.9100  1.3500  0.7400\n_symmetry_space_group_name_H-M   Cmmm\n_cell_length_a   2.6197\n_cell_length_b   4.1349\n_cell_length_c   4.1407\n_cell_angle_alpha   90.0000\n_cell_angle_beta   90.0000\n_cell_angle_gamma   90.0000\n_symmetry_Int_Tables_number   65\n_chemical_formula_structural   CuNi\n_chemical_formula_sum   'Cu2 Ni2'\n_cell_volume   44.8526\n_cell_formula_units_Z   2\nloop_\n _symmetry_equiv_pos_site_id\n _symmetry_equiv_pos_as_xyz\n  1  'x, y, z'\nloop_\n _atom_site_type_symbol\n _atom_site_label\n _atom_site_symmetry_multiplicity\n _atom_site_fract_x\n _atom_site_fract_y\n _atom_site_fract_z\n _atom_site_occupancy\n  Cu  Cu0  2  0.0000  0.5000  0.5000  1\n  Ni  Ni1  2  0.0000  0.0000  0.0000  1\n")

# %%
from cinllm import CIFTokenizer
myop = CIFTokenizer()
myop.tokenize_cif(test_data[2][1])
# Out:
# ['space_group_symbol',
#  ' ',
#  'C2_sg',
#  '\n',
#  'formula',
#  ' ',
#  'K',
#  ' ',
#  '4',
#  ' ',
#  'Hg',
#  ' ',
#  '6',
#  ' ',
#  'Ge',
#  ' ',
#  '4',
#  ' ',
#  'S',
#  ' ',
#  '1',
#  '6',
#  ' ',
#  '\n',
#  'lattice_parameters',
#  ' ',
#  'a',
#  ' ',
#  '9',
#  '.',
#  '7',
#  '9',
#  '5',
#  '5',
#  ' ',
#  'b',
#  ' ',
#  '8',
#  '.',
#  '7',
#  '0',
#  '6',
#  '5',
#  ' ',
#  'c',
#  ' ',
#  '9',
#  '.',
#  '8',
#  '8',
#  '5',
#  '7',
#  ' ',
#  'alpha',
#  ' ',
#  '9',
#  '0',
#  '.',
#  '0',
#  '0',
#  '0',
#  '0',
#  ' ',
#  'beta',
#  ' ',
#  '9',
#  '4',
#  '.',
#  '7',
#  '2',
#  '3',
#  '2',
#  ' ',
#  'gamma',
#  ' ',
#  '9',
#  '0',
#  '.',
#  '0',
#  '0',
#  '0',
#  '0',
#  ' ',
#  '\n',
#  'K',
#  ' ',
#  '0',
#  '.',
#  '2',
#  '1',
#  '6',
#  '5',
#  ' ',
#  '0',
#  '.',
#  '8',
#  '7',
#  '9',
#  '4',
#  ' ',
#  '0',
#  '.',
#  '2',
#  '3',
#  '0',
#  '1',
#  '\n',
#  'Hg',
#  ' ',
#  '0',
#  '.',
#  '0',
#  '0',
#  '0',
#  '0',
#  ' ',
#  '0',
# ...
